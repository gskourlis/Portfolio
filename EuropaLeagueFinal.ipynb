# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from mplsoccer.pitch import Pitch

# %%
df = pd.read_csv('/Users/georgiosskourlis/Desktop/europaFinal.csv')

# %%
df.dropna()
df = df[df['period'].isin(['FirstHalf', 'SecondHalf'])]

# %%
#for i in range(len(df['x'])):
outcome_counts = df.groupby(['teamId','outcome','period']).size().unstack(fill_value=0) 
print (outcome_counts)
# Out:
# period                          FirstHalf  SecondHalf
# teamId            outcome
# Manchester United Successful          395         318
#                   Unsuccessful         79          84
# Villarreal        Successful          220         242
#                   Unsuccessful         83          97

# %%
colors= 'red','yellow'
outcome_counts.plot(kind='bar',color=colors)
plt.xlabel('Team')
plt.ylabel('Count')
ax.legend(fontsize='small')
plt.xticks(rotation=45)
plt.grid(alpha=0.2)
plt.title('Sucessfull/Unsucessfull Passes by Team')
plt.show()

# %%
df['x'] = df['x']*1.2
df['y'] = df['y']*.8
df['endX'] = df['endX']*1.2
df['endY'] = df['endY']*.8

# %%
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

#inverting y axis 
plt.gca().invert_yaxis()
plt.title('Manchester United vs Villareal Successfull Passes (First Half)',color='white')
#ploting the passes for each team 

for x in range(len(df['x'])):
    if df['outcome'][x] == "Successful" and df['teamId'][x]=='Manchester United' and df['x'][x]>60 and df['endX'][x]>60 and df['period'][x]== 'FirstHalf':
        pitch.arrows(df['x'][x], df['y'][x],
             df['endX'][x], df['endY'][x], width=2,
             headwidth=10, headlength=10, color='red', ax=ax, label='completed passes')
        
    if df['outcome'][x] == "Successful" and df['teamId'][x]=='Villarreal' and df['x'][x]<60 and df['endX'][x]<60 and df['period'][x]== 'FirstHalf':
        pitch.arrows(df['x'][x], df['y'][x],
             df['endX'][x], df['endY'][x], width=2,
             headwidth=10, headlength=10, color='yellow', ax=ax, label='completed passes')

# %%
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

#inverting y axis 
plt.gca().invert_yaxis()
plt.title('Manchester United vs Villareal Successfull Passes (Second Half)',color='white')
#ploting the passes for each team 

for x in range(len(df['x'])):
    if df['outcome'][x] == "Successful" and df['teamId'][x]=='Manchester United' and df['x'][x]<60 and df['endX'][x]<60 and df['period'][x]== 'SecondHalf':
        pitch.arrows(df['x'][x], df['y'][x],
             df['endX'][x], df['endY'][x], width=2,
             headwidth=10, headlength=10, color='red', ax=ax, label='completed passes')
        
    if df['outcome'][x] == "Successful" and df['teamId'][x]=='Villarreal' and df['x'][x]>60 and df['endX'][x]>60 and df['period'][x]== 'SecondHalf':
        pitch.arrows(df['x'][x], df['y'][x],
             df['endX'][x], df['endY'][x], width=2,
             headwidth=10, headlength=10, color='yellow', ax=ax, label='completed passes')
